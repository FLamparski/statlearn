# %% [markdown]
# # Analysing the DFE spending data in the summer of 2014

# %%
import numpy as np
import pandas as pd
import matplotlib

# %%
# %matplotlib inline

# %%
# Import data into data frames. Some normalisation will have to be done. Datasets can be downloaded
# at http://data.gov.uk/dataset/financial-transactions-data-dfe
dfe_aug = pd.read_csv('./DfE_Spend_August_2014.csv', parse_dates=True, dayfirst=True)
dfe_jul = pd.read_csv('./DfE_Spend_July_2014_v2.csv', parse_dates=True, dayfirst=True)
dfe_jun = pd.read_csv('./DfE_Spend_June_2014_-_Final_v1.csv', parse_dates=True, dayfirst=True)

# %%
# Column names changed in August, need to normalise
dfe_aug = dfe_aug.rename(columns={'Departmental Family': 'Department family', 'Transaction Number': 'Transaction number'})

# %%
# Get the data for the whole quarter
dfe = pd.concat([dfe_jun, dfe_jul, dfe_aug])

# %%
dfe.Date = pd.to_datetime(dfe.Date)

# %%
dfe.groupby('Supplier').size().order(ascending=False)[:20]
# Out:
# Supplier
# REDFERN TRAVEL LTD                      261
# BT                                      206
# VODAFONE CORPORATE                       93
# CAPITA TP NATWEST                        44
# CAPITA TP HSBC                           40
# PROLOG                                   40
# TPS - FUNDING ACCOUNT 2                  20
# TPS - FUNDING ACCOUNT 1                  18
# CAPGEMINI UK PLC                         17
# INTERSERVE FACILITIES MANAGEMENT LTD     13
# EDUSERV                                  12
# SKILLS FUNDING AGENCY                    12
# EDGE HILL UNIVERSITY                      9
# THE SHARE FOUNDATION 3RD PARTY TRUST      9
# MOTT MACDONALD LTD                        9
# MM TELEPERFORMANCE                        9
# CANTERBURY CHRIST CHURCH UNIVERSITY       9
# UNIVERSITY OF BRIGHTON                    9
# CONTACT A FAMILY                          9
# NFER TRADING LIMITED INV T                9
# dtype: int64

# %%
dfe.groupby('Entity').sum().sort('Amount', ascending=False)
# Out:
#                                                            Amount
# Entity
# DEPARTMENT FOR EDUCATION                             1.388918e+10
# TEACHERS PENSION SCHEME                              2.062404e+09
# NATIONAL COLLEGE FOR TEACHING AND LEADERSHIP AGENCY  4.244385e+07
# NATIONAL COLLEGE FOR SCHOOL LEADERSHIP AGENCY        2.801458e+07
# STANDARDS AND TESTING AGENCY                         2.000894e+07
# EDUCATION FUNDING AGENCY                             5.749908e+04

# %%
dfe[dfe.Entity == 'DEPARTMENT FOR EDUCATION'].groupby('Expense area').sum().sort('Amount', ascending=False)
# Out:
#                                                                                Amount
# Expense area
# Various                                                                  1.370541e+10
# Childcare, Special Educational Needs and Children's Strategy Group       5.889352e+07
# Curriculum and General Qualifications Reform Group                       2.099009e+07
# Children in Care Division                                                1.795662e+07
# Academies Delivery Group                                                 1.365899e+07
# Closing the Gap Group                                                    1.258257e+07
# Finance and Commercial Group - Property Asset Management                 9.240938e+06
# Free School Group                                                        8.223075e+06
# Systems and Accountability Group                                         7.021527e+06
# Teachers and Teaching Group                                              6.591867e+06
# System Reform Group                                                      6.590736e+06
# Chief Information Officer Group                                          6.577156e+06
# Families Group                                                           5.243937e+06
# Children's Services and Departmental Strategy Safeguarding Group         4.598457e+06
# Strategic Analysis and Research and Policy Impact Group                  1.433513e+06
# Finance and Commercial Group                                             1.012937e+06
# Legal Advisers Office                                                    1.012926e+06
# Children's Services and Departmental Strategy Supporting Delivery Group  6.529404e+05
# Safeguarding Group                                                       3.984423e+05
# School Standards Group                                                   3.199023e+05
# Children's Services and Departmental Strategy Directorate Support        2.585371e+05
# People and Change                                                        1.514525e+05
# Human Resources Group                                                    1.447512e+05
# Communications Group                                                     1.094796e+05
# Education Funding Group                                                  5.545614e+04
# Private Office                                                           4.581965e+04
# Education Standards Directorate                                          6.321970e+03
# Infrastructure and Funding Directorate Support                           2.694860e+03
# Child Poverty Group                                                      6.711600e+02
# Office of the Schools Commissioner Group                                -3.763900e+02

# %%
# Let's actually make it time series data
dfe.index = dfe.Date

# %%
dfe.head()
# Out:
#                Amount       Date         Department family  \
# Date
# 2014-10-06   42264.06 2014-10-06  Department for Education
# 2014-11-06   54000.00 2014-11-06  Department for Education
# 2014-06-16   25000.00 2014-06-16  Department for Education
# 2014-06-16     -53.65 2014-06-16  Department for Education
# 2014-06-16  103213.52 2014-06-16  Department for Education
#
#                    Description  \
# Date
# 2014-10-06  Marketing services
# 2014-11-06  Marketing services
# 2014-06-16        ICT Services
# 2014-06-16  Marketing services
# 2014-06-16  Marketing services
#
#                                                        Entity  \
# Date
# 2014-10-06  NATIONAL COLLEGE FOR TEACHING AND LEADERSHIP A...
# 2014-11-06                           DEPARTMENT FOR EDUCATION
# 2014-06-16                           DEPARTMENT FOR EDUCATION
# 2014-06-16                           DEPARTMENT FOR EDUCATION
# 2014-06-16  NATIONAL COLLEGE FOR TEACHING AND LEADERSHIP A...
#
#                                 Expense area    Expense type         Supplier  \
# Date
# 2014-10-06            Operations Directorate  Communications  CREATIVE CHOICE
# 2014-11-06              Communications Group  Communications   CABINET OFFICE
# 2014-06-16  Systems and Accountability Group             ICT    SCISYS UK LTD
# 2014-06-16              Communications Group  Communications              M4C
# 2014-06-16            Operations Directorate  Communications              M4C
#
#            Transaction number
# Date
# 2014-10-06         4000173016
# 2014-11-06         4000173172
# 2014-06-16         4000173433
# 2014-06-16         4000173513
# 2014-06-16         4000173513

# %%
dfe.groupby('Expense type').sum().sort('Amount', ascending=False)
# Out:
#                                                                  Amount
# Expense type
# Redactions                                                 1.370541e+10
# Funding to Pay Teachers' Pensions                          2.065526e+09
# Grants                                                     1.891532e+08
# Programme costs                                            4.480605e+07
# Professional Services Other                                1.061934e+07
# Facilities                                                 8.886075e+06
# ICT                                                        7.092827e+06
# Office Solutions                                           4.946647e+06
# Professional Services Consultancy and Contingent Labour    2.051927e+06
# Communications                                             1.229820e+06
# Travel                                                     1.108911e+06
# Energy and Fuels                                           3.677381e+05
# Personnel Related                                          3.288944e+05
# Print and Print Management                                 2.750991e+05
# Miscellaneous Expenditure                                  1.789853e+05
# Operational Goods                                          1.322586e+05
# ? Professional Services Consultancy and Contingent Labour -2.300000e-01
